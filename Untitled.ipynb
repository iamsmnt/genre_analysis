# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#                                            book_name               author  \
# 0                   The 100 Most Notable Cornellians  Glenn C. Altschuler
# 1                    Mientras Nieva Sobre Los Cedros       David Guterson
# 2                              The Lord of the Rings       J.R.R. Tolkien
# 3                          Beyond Silence and Denial         Lucy Bregman
# 4  African Rock Art: Paintings and Engravings on ...        David Coulson
#
#   rating   votes num_reviews  \
# 0      4       1           0
# 1   3.82  151415        4241
# 2   4.49  479889       10298
# 3    3.8       5           0
# 4      5       3           0
#
#                                          description no_of_pages  \
# 0  "Cornell is unique among American research uni...         272
# 1  You know that guy who's at every party, the on...         400
# 2  The Fellowship of the Ring, part one of J.R.R....        1184
# 3  Lucy Bregman guides the reader through the wea...         208
# ...

# %%
df.shape
# Out:
# (2183, 18)

# %%
missing_vals = pd.DataFrame(df.isnull().sum()).reset_index().rename(index=str, columns={"index": "columns", 0: "missing values"})

# %%
missing_vals.astype({"missing values": int})
# Out:
#         columns  missing values
# 0     book_name               0
# 1        author               0
# 2        rating               0
# 3         votes               0
# 4   num_reviews               0
# 5   description               0
# 6   no_of_pages              85
# 7        isbn13              33
# 8         genre             370
# 9       reviews             377
# 10  Unnamed: 10            2145
# 11  Unnamed: 11            2178
# 12  Unnamed: 12            2180
# 13  Unnamed: 13            2181
# 14  Unnamed: 14            2182
# 15  Unnamed: 15            2182
# 16  Unnamed: 16            2182
# 17  Unnamed: 17            2182

# %%
def colmn():
# Out:
# 218.3
